# %% [markdown]
# <a href="https://colab.research.google.com/github/khagendra1998/A-rule-based-expert-system-to-identify-the-type-of-cybercrime/blob/master/Prediction_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PORTMAP DATASET**

# %% [markdown]
# **Load the data from the google drive**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Load the Data from CSV file

data = pd.read_csv("/content/drive/My Drive/Datasets/Portmap.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (85) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **Show the First Five rows of the Dataset**

# %%
data.head()
# Out:
#    Unnamed: 0                                 Flow ID  ...  Inbound   Label
# 0          24          192.168.50.254-224.0.0.5-0-0-0  ...        0  BENIGN
# 1          26          192.168.50.253-224.0.0.5-0-0-0  ...        0  BENIGN
# 2      176563  172.217.10.98-192.168.50.6-443-54799-6  ...        0  BENIGN
# 3       50762    172.217.7.2-192.168.50.6-443-54800-6  ...        0  BENIGN
# 4       87149  172.217.10.98-192.168.50.6-443-54801-6  ...        0  BENIGN
#
# [5 rows x 88 columns]

# %% [markdown]
# **Description of the dataset**

# %%
data.describe()
# Out:
#           Unnamed: 0    Source Port  ...      Idle Min        Inbound
# count  191694.000000  191694.000000  ...  1.916940e+05  191694.000000
# mean    95846.500000    2088.157068  ...  1.110960e+05       0.977146
# std     55337.435588    8566.647296  ...  2.326992e+06       0.149439
# min         0.000000       0.000000  ...  0.000000e+00       0.000000
# 25%     47923.250000     648.000000  ...  0.000000e+00       1.000000
# 50%     95846.500000     651.000000  ...  0.000000e+00       1.000000
# 75%    143769.750000     846.000000  ...  0.000000e+00       1.000000
# max    191693.000000   65528.000000  ...  8.279180e+07       1.000000
#
# [8 rows x 82 columns]

# %% [markdown]
# **Make the List of the Relevant Columns of Dataset**
#
# It can be analysis by the CICFlowMeter
# this the URL of the CICFlowMeter
#
# http://netflowmeter.ca/

# %%
irr = [' Fwd Packet Length Max',
    ' Fwd Packet Length Min',
    ' Min Packet Length',
    ' Max Packet Length',
    ' Average Packet Size',
    'Fwd Packets/s',
    ' Fwd Header Length',
    ' Fwd Header Length.1',
    ' min_seg_size_forward',
    'Total Length of Fwd Packets',
    ' Fwd Packet Length Std',
    ' Flow IAT Min',
    ' Subflow Fwd Bytes',
    ' Destination Port',
    ' Protocol',
    ' Packet Length Std',
    ' Flow Duration',
    'Fwd IAT Total',
    ' ACK Flag Count',
    'Init_Win_bytes_forward',
    ' Flow IAT Mean',
    ' Flow IAT Max',
    ' Fwd IAT Mean',
    ' Fwd IAT Max']

# %%
print(len(irr))
# Out:
# 24

# %% [markdown]
# **Here we remove the Irrevelent Columns except Revelent Column List which is defined above**

# %%
remove_col = []
for mycol in data.columns:
    if all (x not in mycol for x in irr):
        remove_col.append(mycol)

# %%
print(remove_col)
print(len(remove_col))
# Out:
# ['Unnamed: 0', 'Flow ID', ' Source IP', ' Source Port', ' Destination IP', ' Timestamp', ' Total Fwd Packets', ' Total Backward Packets', ' Total Length of Bwd Packets', ' Fwd Packet Length Mean', 'Bwd Packet Length Max', ' Bwd Packet Length Min', ' Bwd Packet Length Mean', 'Flow Bytes/s', ' Flow Packets/s', ' Flow IAT Std', ' Fwd IAT Std', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags', ' Bwd Header Length', ' Bwd Packets/s', ' Packet Length Mean', ' Packet Length Variance', 'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count', ' URG Flag Count', ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio', ' Avg Fwd Segment Size', ' Avg Bwd Segment Size', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Bwd Packets', ' Subflow B
# ...

# %%
data = data.drop(['Unnamed: 0',
'Flow ID',
' Source IP',
' Source Port',
' Destination IP',
' Timestamp',
' Total Fwd Packets',
' Total Backward Packets',
' Total Length of Bwd Packets',
' Fwd Packet Length Mean',
'Bwd Packet Length Max',
' Bwd Packet Length Min',
' Bwd Packet Length Mean',
'Flow Bytes/s',
' Flow Packets/s',
' Flow IAT Std',
' Fwd IAT Std',
' Fwd IAT Min',
'Bwd IAT Total',
' Bwd IAT Mean',
' Bwd IAT Std',
' Bwd IAT Max',
' Bwd IAT Min',
'Fwd PSH Flags',
' Bwd PSH Flags',
' Fwd URG Flags',
' Bwd URG Flags',
' Bwd Header Length',
' Bwd Packets/s',
' Packet Length Mean',
' Packet Length Variance',
'FIN Flag Count',
' SYN Flag Count',
' RST Flag Count',
' PSH Flag Count',
' URG Flag Count',
' CWE Flag Count',
' ECE Flag Count',
' Down/Up Ratio',
' Avg Fwd Segment Size',
' Avg Bwd Segment Size',
'Fwd Avg Bytes/Bulk',
' Fwd Avg Packets/Bulk',
' Fwd Avg Bulk Rate',
' Bwd Avg Bytes/Bulk',
' Bwd Avg Packets/Bulk',
'Bwd Avg Bulk Rate',
'Subflow Fwd Packets',
' Subflow Bwd Packets',
' Subflow Bwd Bytes',
' Init_Win_bytes_backward',
' act_data_pkt_fwd',
'Active Mean',
' Active Std',
' Active Max',
' Active Min',
'Idle Mean',
' Idle Std',
' Idle Max',
' Idle Min',
'SimillarHTTP',
' Inbound'],axis=1)
data.head()
# Out:
#     Destination Port   Protocol  ...   min_seg_size_forward   Label
# 0                  0          0  ...                      0  BENIGN
# 1                  0          0  ...                      0  BENIGN
# 2                443          6  ...                     20  BENIGN
# 3                443          6  ...                     20  BENIGN
# 4                443          6  ...                     20  BENIGN
#
# [5 rows x 26 columns]

# %% [markdown]
# **Shape of the Clean Dataset**

# %%
data.shape
# Out:
# (191694, 26)

# %% [markdown]
# **Check any Column have empty space**

# %%
data.isnull().sum()
# Out:
#  Destination Port              0
#  Protocol                      0
#  Flow Duration                 0
# Total Length of Fwd Packets    0
#  Fwd Packet Length Max         0
#  Fwd Packet Length Min         0
#  Fwd Packet Length Std         0
#  Bwd Packet Length Std         0
#  Flow IAT Mean                 0
#  Flow IAT Max                  0
#  Flow IAT Min                  0
# Fwd IAT Total                  0
#  Fwd IAT Mean                  0
#  Fwd IAT Max                   0
#  Fwd Header Length             0
# Fwd Packets/s                  0
#  Min Packet Length             0
#  Max Packet Length             0
#  Packet Length Std             0
#  ACK Flag Count                0
#  Average Packet Size           0
#  Fwd Header Length.1           0
#  Subflow Fwd Bytes             0
# Init_Win_bytes_forward         0
#  min_seg_size_forward          0
#  Label                         0
# dtype: int64

# %% [markdown]
# **Here no column have the empty space of NULL values all columns are the full**

# %% [markdown]
# **This we check the Object datatype column in the dataset**

# %%
for i in data.columns:
    if(data[i].dtype == np.object):
        print(i)
# Out:
#  Label

# %% [markdown]
# **Divide the data into two parts in X and Y**

# %%
y = data[' Label']
x = data.drop([' Label'],axis=1)

print("\n<<====================== X ================================>>\n",x)
print("\n<<====================== Y ================================>>\n",y)
# Out:
# <<====================== X ================================>>
#           Destination Port  ...   min_seg_size_forward
# 0                       0  ...                      0
# 1                       0  ...                      0
# 2                     443  ...                     20
# 3                     443  ...                     20
# 4                     443  ...                     20
# ...                   ...  ...                    ...
# 191689              47131  ...                     20
# 191690              53617  ...                     20
# 191691               9612  ...                     20
# 191692              23408  ...                     20
# 191693              50418  ...                     20
#
# [191694 rows x 25 columns]
#
# <<====================== Y ================================>>
#  0          BENIGN
# 1          BENIGN
# 2          BENIGN
# 3          BENIGN
# 4          BENIGN
#            ...
# 191689    Portmap
# 191690    Portmap
# ...

# %% [markdown]
# **Split the dataset into the x_train, x_test, y_train, y_test**
#
# **Split Ratio into Test and train is 30:70 means that 30% of the total data is goes for the test and 70% of the total data is goes for the training.**

# %%
#split data into training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,
                                               test_size=0.30,
                                               random_state=42)
print("\n<<======== X_Train ========>>\n",x_train.shape)
print("\n<<======== X_Train ========>>\n",y_train.shape)
print("\n<<======== X_Test ========>>\n",x_test.shape)
print("\n<<======== Y_Test ========>>\n",y_test.shape)
# Out:
# <<======== X_Train ========>>
#  (134185, 25)
#
# <<======== X_Train ========>>
#  (134185,)
#
# <<======== X_Test ========>>
#  (57509, 25)
#
# <<======== Y_Test ========>>
#  (57509,)

# %% [markdown]
# #**LOGISTIC REGRESSION**

# %% [markdown]
# **Fiting the model in the Logistic Regression Algorithm**

# %%
#fitting the logistic regression model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression( random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#predicting the test result
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# ['Portmap' 'Portmap' 'Portmap' ... 'Portmap' 'Portmap' 'Portmap']

# %% [markdown]
# **Confusion Matrix of the Logisitic Regression**

# %%
#checking the accuracy of model

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cfm = confusion_matrix(y_test, y_pred)
print("\n<<================= Confusion Matrix ======================>> \n",cfm)
# Out:
# <<================= Confusion Matrix ======================>>
#  [[  975   440]
#  [   51 56043]]

# %% [markdown]
# **Classification Report of the Logistic Regeression**

# %%
## Classification Report

print("\n<<==================== Calssification Report ====================>>\n")

print (classification_report(y_test, y_pred))
# Out:
# <<==================== Calssification Report ====================>>
#
#               precision    recall  f1-score   support
#
#       BENIGN       0.95      0.69      0.80      1415
#      Portmap       0.99      1.00      1.00     56094
#
#     accuracy                           0.99     57509
#    macro avg       0.97      0.84      0.90     57509
# weighted avg       0.99      0.99      0.99     57509

# %% [markdown]
# **Accuracy of the Logistic Regression**

# %%
## Accuracy Of The Model In the Linear Regression Algo
acc = accuracy_score(y_test, y_pred)
print ('\n<<================================ Accuracy Of the Model in LR Algo ================================>>\n', acc*100)
# Out:
# <<================================ Accuracy Of the Model in LR Algo ================================>>
#  99.14622059155958

# %%
############ 
from sklearn.metrics import accuracy_score
print("Model Accuracy is : \n ",accuracy_score(y_test,y_pred))
# Out:
# Model Accuracy is :
#   0.9914622059155959

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print(classification_report(y_test,y_pred))
print("\n\n <<===================================>> \n\n")
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       BENIGN       0.95      0.69      0.80      1415
#      Portmap       0.99      1.00      1.00     56094
#
#     accuracy                           0.99     57509
#    macro avg       0.97      0.84      0.90     57509
# weighted avg       0.99      0.99      0.99     57509
#
#
#
#  <<===================================>>
#
#
# [[  975   440]
#  [   51 56043]]

# %%
y_pred = classifier.predict(x_test.values[[5]])
print(y_pred)
# Out:
# ['Portmap']

# %% [markdown]
# #**Enter the The Detail By User**

# %%
user = []
user.append(int(input("Destination Port             ====>>")))            
user.append(int(input("Protocol                     ====>>")))                      
user.append(int(input("Flow Duration                ====>>")))                 
user.append(float(input("Total Length of Fwd Packets  ====>>")))    
user.append(float(input("Fwd Packet Length Max        ====>>")))         
user.append(float(input("Fwd Packet Length Min        ====>>")))         
user.append(float(input("Fwd Packet Length Std        ====>>")))         
user.append(float(input("Bwd Packet Length Std        ====>>")))         
user.append(float(input("Flow IAT Mean                ====>>")))                 
user.append(float(input("Flow IAT Max                 ====>>")))                  
user.append(float(input("Flow IAT Min                 ====>>")))                  
user.append(float(input("Fwd IAT Total                ====>>")))                  
user.append(float(input("Fwd IAT Mean                 ====>>")))                  
user.append(float(input("Fwd IAT Max                  ====>>")))                   
user.append(int(input("Fwd Header Length            ====>>")))             
user.append(float(input("Fwd Packets/s                ====>>")))                  
user.append(float(input("Min Packet Length            ====>>")))             
user.append(float(input("Max Packet Length            ====>>")))             
user.append(float(input("Packet Length Std            ====>>")))             
user.append(int(input("ACK Flag Count               ====>>")))                
user.append(float(input("Average Packet Size          ====>>")))           
user.append(int(input("Fwd Header Length.1          ====>>")))           
user.append(int(input("Subflow Fwd Bytes            ====>>")))             
user.append(int(input("Init_Win_bytes_forward       ====>>")))         
user.append(int(input("min_seg_size_forward         ====>>"))) 

print([user])
# Out:
# Destination Port             ====>>443
# Protocol                     ====>>6
# Flow Duration                ====>>36434620
# Total Length of Fwd Packets  ====>>116.0
# Fwd Packet Length Max        ====>>49.0
# Fwd Packet Length Min        ====>>6.2
# Fwd Packet Length Std        ====>>20.99
# Bwd Packet Length Std        ====>>1.2
# Flow IAT Mean                ====>>5.6
# Flow IAT Max                 ====>>36348856.0
# Flow IAT Min                 ====>>1.2
# Fwd IAT Total                ====>>36434346.0
# Fwd IAT Mean                 ====>>8.2
# Fwd IAT Max                  ====>>32564515.0
# Fwd Header Length            ====>>125
# Fwd Packets/s                ====>>0.5
# Min Packet Length            ====>>5.0
# Max Packet Length            ====>>48.0
# Packet Length Std            ====>>22.0
# ACK Flag Count               ====>>0
# Average Packet Size          ====>>31.78
# Fwd Header Length.1          ====>>140
# Subflow Fwd Bytes            ====>>115
# ...

# %%
y_pred = classifier.predict([user])
print("According to Your Entered Information Attack is ",y_pred[0]," DDos Attack")
# Out:
# According to Your Entered Information Attack is  BENIGN  DDos Attack
